# %% [markdown]
# # Week 02 – Glassbox Models (part 2)
#
# In this notebook we'll be applying different glassbox models to the same dataset and compare their performance in terms of accuracy and f1-score and their interpretability.
#
# #### Step 1: Navigate to this week's directory
# ```
# cd <path_to_week_2_material>
# ```
#
# #### Step 2: Create and Activate a virtual environment (Python 3.9)
# **MacOS**
# ```
# python3.11 -m venv part2_venv
# source part2_venv/bin/activate
# ```
#
# **Windows (cmd)**
# ```
# python3.11 -m venv part2_venv
# part2_venv\Scripts\activate
# ```
#
# #### Step 3: Install required packages
# First, install `ipykernel` to integrate your virtual environment with Jupyter.
# ```
# pip install ipykernel
# python -m ipykernel install --user --name=part2_venv
# ```
#
# Next, install all necessary packages.
# ```
# pip install ruleopt
# ```
#
# **import packages**

# %%
import warnings
warnings.filterwarnings("ignore")
import numpy as np
import pandas as pd
from sklearn.metrics import accuracy_score, f1_score, confusion_matrix, roc_auc_score
import os
import sys
# import matplotlib.pyplot as plt

# %% [markdown]
# # Load the dataset
#
# We are using the [Titanic dataset](https://www.kaggle.com/c/titanic/overview), which holds data about passangers of the Titanic and whether they survived or not. Passengers are described by 7 features. The response variable is binary (0 – died; 1 - survived).
#
# Make sure to save the dataset in the parent directory or adjust the file path below.
#
# We are directly loading the pre-processed data sets. For some algorithms, we require the data to be in binary form. Hence, we have two versions of X: `X_train` and `X_test`, with continous features and one-hot encoded categorical features, and `X_train_bin` and `X_test_bin`, where all features have been one-hot encoded. For this, continuous features were first transformed into categories. Check the code in `./01_intro/titanic_data_prep.ipynb` for more details on pre-processing.

# %%
# X_train 
X_train = pd.read_csv('../datasets/titanic/encoded_titanic_X_train.csv')
X_train_bin = pd.read_csv('../datasets/titanic/bin_titanic_X_train.csv')

# X_test
X_test = pd.read_csv('../datasets/titanic/encoded_titanic_X_test.csv')
X_test_bin = pd.read_csv('../datasets/titanic/bin_titanic_X_test.csv')

# y_train and y_test
y_train = pd.read_csv('../datasets/titanic/titanic_y_train.csv')
y_test = pd.read_csv('../datasets/titanic/titanic_y_test.csv')

# take a look at the data
X_train.head()
# Out:
#          Age  SibSp  Parch     Fare  Sex_1  Embarked_1  Embarked_2  Pclass_1  \
# 0  29.699118      0      0   7.6292      0           1           0         0
# 1  29.699118      0      0   8.0500      1           0           1         0
# 2  29.699118      0      0   7.7500      0           1           0         0
# 3  51.000000      1      0  77.9583      0           0           1         0
# 4  21.000000      0      0   7.7333      1           1           0         0
#
#    Pclass_2
# 0         1
# 1         1
# 2         1
# 3         0
# 4         1

# %% [markdown]
# ## About the dataset
#
# - `Age` – age of a person in years (int)
# - `SibSp` – the number of siblings or spouse of a person **onboard** (int)
# - `Parch` – the number of parents or children of a person **onbard** (int)
# - `Fare` – ticket price (float)
# - `Sex` – sex of a person (categorical/binary)
# - `Embarked` – location where the traveler mounted from. There are three possible values — Southampton, Cherbourg, and Queenstown (categorical)
# - `Pclass` – passenger division into class 1, 2, and 3 (categorical)
# - `Survived` – whether person survived the sinking of the ship (binary). Less than 40% survived. This is the **outcome** to predict.
#
#
# From the original dataset and from preprocessing the data, we know the following about the **categorical features**:
#
# - `Sex` has two values `['female','male']`, which were encoded `[0,1]`, respectively. Then, after applying one-hot encoding, we have `Sex_1` which indicates `male` if 1, `female` otherwise.
# - `Embarked` has three values `['C', 'Q', 'S']`, which were encoded `[0,1,2]`, respectively. Hence,
#     - `Embarked_1 = 1` indicates `Q`
#     - `Embarked_2 = 1` indicates `S`
#     - `Embarked_1 = 0` and `Embarked_2 = 0` indicated `C`
# - `Pclass` has three values `[1,2,3]`, which were encoded `[0,1,2]`, respectively. Hence, after encoding, we have:
#     - `Pclass_1 = 1` indicates `2`
#     - `Pclass_2 = 1` indicates `3`
#     - `Pclass_1 = 0` and `Pclass_2 = 0` indicates `1`

# %%
d = {
    'target': 'Survived',
    'numerical':['Age', 'SibSp', 'Parch', 'Fare'],
    'categorical':['Sex', 'Embarked', 'Pclass']
}

# save feature names
feature_names = X_train.columns
target_names = list(y_train[d['target']].unique())

# create a dataframe to save y values in 
y_results = pd.DataFrame()
y_results['y_test'] = y_test

# %% [markdown]
# ---
# ---

# %% [markdown]
# # 5. Decision Rules
#
# ## 5.2 Rule Generation (RUG)
#
# We propose this algorithm in our paper which you can access here: https://arxiv.org/abs/2104.10751

# %%
# sys.path.insert(1, os.path.dirname(os.getcwd())+'/RuleDiscovery')
from ruleopt import RUGClassifier
from ruleopt.rule_cost import Length, Gini
from ruleopt.explainer import Explainer
# import ruxg
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 2
#       1 # sys.path.insert(1, os.path.dirname(os.getcwd())+'/RuleDiscovery')
# ----> 2 from ruleopt import RUGClassifier
#       3 from ruleopt.rule_cost import Length, Gini
#       4 from ruleopt.explainer import Explainer
#
# File ~/Programs/UvA Master/Trustworthy AI/trustworthy_ai/02_glassbox/part2_venv/lib/python3.11/site-packages/ruleopt/__init__.py:1
# ----> 1 from .estimator import (RUGClassifier, RUXClassifier, RUXLGBMClassifier, RUXXGBClassifier)
#       2 from .explainer import Explainer
#       4 __all__ = [
#       5     "RUGClassifier",
#       6     "RUXClassifier",
#       7     "RUXLGBMClassifier",
#       8     "RUXXGBClassifier",
#       9     "Explainer",]
#
# File ~/Programs/UvA Master/Trustworthy AI/trustworthy_ai/02_glassbox/part2_venv/lib/python3.11/site-packages/ruleopt/estimator/__init__.py:1
# ----> 1 from .sklearn_.rug import (RUGClassifier)
#       2 from .sklearn_.rux import (RUXClassifier)
#       3 from .xgboost_ import (RUXXGBClassifier)
#
# File ~/Programs/UvA Master/Trustworthy AI/trustworthy_ai/02_glassbox/part2_venv/lib/python3.11/site-packages/ruleopt/estimator/sklearn_/__init__.py:1
# ----> 1 from .rug import RUGClassifier
#       2 from .rux import RUXClassifier
#       4 __all__ = [
#       5     "RUGClassifier",
#       6     "RUXClassifier",
#       7 ]
#
# File ~/Programs/UvA Master/Trustworthy AI/trustworthy_ai/02_glassbox/part2_venv/lib/python3.11/site-packages/ruleopt/estimator/sklearn_/rug.py:5
#       3 import numpy as np
#       4 from numpy.typing import ArrayLike
# ----> 5 from sklearn.tree import DecisionTreeClassifier
#       7 from .base_sklearn import _RUGSKLEARN
#       8 from ...rule_cost import Gini
#
# File ~/Programs/UvA Master/Trustworthy AI/trustworthy_ai/02_glassbox/part2_venv/lib/python3.11/site-packages/sklearn/tree/__init__.py:6
#       1 """Decision tree based models for classification and regression."""
#       3 # Authors: The scikit-learn developers
#       4 # SPDX-License-Identifier: BSD-3-Clause
# ----> 6 from sklearn.tree._classes import (
#       7     BaseDecisionTree,
#       8     DecisionTreeClassifier,
#       9     DecisionTreeRegressor,
#      10     ExtraTreeClassifier,
#      11     ExtraTreeRegressor,
#      12 )
#      13 from sklearn.tree._export import export_graphviz, export_text, plot_tree
#      15 __all__ = [
#      16     "BaseDecisionTree",
#      17     "DecisionTreeClassifier",
#    (...)     23     "plot_tree",
#      24 ]
#
# File ~/Programs/UvA Master/Trustworthy AI/trustworthy_ai/02_glassbox/part2_venv/lib/python3.11/site-packages/sklearn/tree/_classes.py:27
#      16 from scipy.sparse import issparse
#      18 from sklearn.base import (
#      19     BaseEstimator,
#      20     ClassifierMixin,
#    (...)     25     is_classifier,
#      26 )
# ---> 27 from sklearn.tree import _criterion, _splitter, _tree
#      28 from sklearn.tree._criterion import Criterion
#      29 from sklearn.tree._splitter import Splitter
#
# File ~/Programs/UvA Master/Trustworthy AI/trustworthy_ai/02_glassbox/part2_venv/lib/python3.11/site-packages/sklearn/tree/_criterion.pyx:1, in init sklearn.tree._criterion()
#
# File ~/Programs/UvA Master/Trustworthy AI/trustworthy_ai/02_glassbox/part2_venv/lib/python3.11/site-packages/sklearn/tree/_splitter.pyx:1, in init sklearn.tree._splitter()
#
# File ~/Programs/UvA Master/Trustworthy AI/trustworthy_ai/02_glassbox/part2_venv/lib/python3.11/site-packages/sklearn/tree/_tree.pyx:1, in init sklearn.tree._tree()
#
# File ~/Programs/UvA Master/Trustworthy AI/trustworthy_ai/02_glassbox/part2_venv/lib/python3.11/site-packages/sklearn/neighbors/__init__.py:25
#      23 from sklearn.neighbors._kde import KernelDensity
#      24 from sklearn.neighbors._lof import LocalOutlierFactor
# ---> 25 from sklearn.neighbors._nca import NeighborhoodComponentsAnalysis
#      26 from sklearn.neighbors._nearest_centroid import NearestCentroid
#      27 from sklearn.neighbors._regression import KNeighborsRegressor, RadiusNeighborsRegressor
#
# File ~/Programs/UvA Master/Trustworthy AI/trustworthy_ai/02_glassbox/part2_venv/lib/python3.11/site-packages/sklearn/neighbors/_nca.py:22
#      14 from scipy.optimize import minimize
#      16 from sklearn.base import (
#      17     BaseEstimator,
#      18     ClassNamePrefixFeaturesOutMixin,
#      19     TransformerMixin,
#      20     _fit_context,
#      21 )
# ---> 22 from sklearn.decomposition import PCA
#      23 from sklearn.exceptions import ConvergenceWarning
#      24 from sklearn.metrics import pairwise_distances
#
# File ~/Programs/UvA Master/Trustworthy AI/trustworthy_ai/02_glassbox/part2_venv/lib/python3.11/site-packages/sklearn/decomposition/__init__.py:10
#       1 """Matrix decomposition algorithms.
#       2
#       3 These include PCA, NMF, ICA, and more. Most of the algorithms of this module can be
#       4 regarded as dimensionality reduction techniques.
#       5 """
#       7 # Authors: The scikit-learn developers
#       8 # SPDX-License-Identifier: BSD-3-Clause
# ---> 10 from sklearn.decomposition._dict_learning import (
#      11     DictionaryLearning,
#      12     MiniBatchDictionaryLearning,
#      13     SparseCoder,
#      14     dict_learning,
#      15     dict_learning_online,
#      16     sparse_encode,
#      17 )
#      18 from sklearn.decomposition._factor_analysis import FactorAnalysis
#      19 from sklearn.decomposition._fastica import FastICA, fastica
#
# File ~/Programs/UvA Master/Trustworthy AI/trustworthy_ai/02_glassbox/part2_venv/lib/python3.11/site-packages/sklearn/decomposition/_dict_learning.py:21
#      13 from scipy import linalg
#      15 from sklearn.base import (
#      16     BaseEstimator,
#      17     ClassNamePrefixFeaturesOutMixin,
#      18     TransformerMixin,
#      19     _fit_context,
#      20 )
# ---> 21 from sklearn.linear_model import Lars, Lasso, LassoLars, orthogonal_mp_gram
#      22 from sklearn.utils import check_array, check_random_state, gen_batches, gen_even_slices
#      23 from sklearn.utils._param_validation import Interval, StrOptions, validate_params
#
# File ~/Programs/UvA Master/Trustworthy AI/trustworthy_ai/02_glassbox/part2_venv/lib/python3.11/site-packages/sklearn/linear_model/__init__.py:11
#       3 # Authors: The scikit-learn developers
#       4 # SPDX-License-Identifier: BSD-3-Clause
#       5
#       6 # See http://scikit-learn.sourceforge.net/modules/sgd.html and
#       7 # http://scikit-learn.sourceforge.net/modules/linear_model.html for
#       8 # complete documentation.
#      10 from sklearn.linear_model._base import LinearRegression
# ---> 11 from sklearn.linear_model._bayes import ARDRegression, BayesianRidge
#      12 from sklearn.linear_model._coordinate_descent import (
#      13     ElasticNet,
#      14     ElasticNetCV,
#    (...)     22     lasso_path,
#      23 )
#      24 from sklearn.linear_model._glm import GammaRegressor, PoissonRegressor, TweedieRegressor
#
# File ~/Programs/UvA Master/Trustworthy AI/trustworthy_ai/02_glassbox/part2_venv/lib/python3.11/site-packages/sklearn/linear_model/_bayes.py:26
#      20 from sklearn.utils.validation import _check_sample_weight, validate_data
#      22 ###############################################################################
#      23 # BayesianRidge regression
# ---> 26 class BayesianRidge(RegressorMixin, LinearModel):
#      27     """Bayesian ridge regression.
#      28
#      29     Fit a Bayesian ridge model. See the Notes section for details on this
#    (...)    169     array([1.])
#     170     """
#     172     _parameter_constraints: dict = {
#     173         "max_iter": [Interval(Integral, 1, None, closed="left")],
#     174         "tol": [Interval(Real, 0, None, closed="neither")],
#    (...)    184         "verbose": ["verbose"],
#     185     }
#
# File ~/Programs/UvA Master/Trustworthy AI/trustworthy_ai/02_glassbox/part2_venv/lib/python3.11/site-packages/sklearn/linear_model/_bayes.py:173, in BayesianRidge()
#      26 class BayesianRidge(RegressorMixin, LinearModel):
#      27     """Bayesian ridge regression.
#      28
#      29     Fit a Bayesian ridge model. See the Notes section for details on this
#    (...)    169     array([1.])
#     170     """
#     172     _parameter_constraints: dict = {
# --> 173         "max_iter": [Interval(Integral, 1, None, closed="left")],
#     174         "tol": [Interval(Real, 0, None, closed="neither")],
#     175         "alpha_1": [Interval(Real, 0, None, closed="left")],
#     176         "alpha_2": [Interval(Real, 0, None, closed="left")],
#     177         "lambda_1": [Interval(Real, 0, None, closed="left")],
#     178         "lambda_2": [Interval(Real, 0, None, closed="left")],
#     179         "alpha_init": [None, Interval(Real, 0, None, closed="left")],
#     180         "lambda_init": [None, Interval(Real, 0, None, closed="left")],
#     181         "compute_score": ["boolean"],
#     182         "fit_intercept": ["boolean"],
#     183         "copy_X": ["boolean"],
#     184         "verbose": ["verbose"],
#     185     }
#     187     def __init__(
#     188         self,
#     189         *,
#    (...)    201         verbose=False,
#     202     ):
#     203         self.max_iter = max_iter
#
# File ~/Programs/UvA Master/Trustworthy AI/trustworthy_ai/02_glassbox/part2_venv/lib/python3.11/site-packages/sklearn/utils/_param_validation.py:445, in Interval.__init__(self, type, left, right, closed)
#     442 self.right = right
#     443 self.closed = closed
# --> 445 self._check_params()
#
# File ~/Programs/UvA Master/Trustworthy AI/trustworthy_ai/02_glassbox/part2_venv/lib/python3.11/site-packages/sklearn/utils/_param_validation.py:462, in Interval._check_params(self)
#     460 if self.type is Integral:
#     461     suffix = "for an interval over the integers."
# --> 462     if self.left is not None and not isinstance(self.left, Integral):
#     463         raise TypeError(f"Expecting left to be an int {suffix}")
#     464     if self.right is not None and not isinstance(self.right, Integral):
#
# File <frozen abc>:119, in __instancecheck__(cls, instance)
#
# File <frozen abc>:123, in __subclasscheck__(cls, subclass)
#
# KeyboardInterrupt:

# %%
# solver = ORToolsSolver()
rule_cost = Length()

# Initialize the RUGClassifier with specific parameters
rug = RUGClassifier(
    random_state=100,
    max_rmp_calls=8,
    rule_cost=rule_cost,
    max_depth=3,
    threshold=0.05)

# %%
# rug = RUGClassifier(max_depth=3, rule_length_cost=False,
#                     solver='gurobi', random_state=0, max_RMP_calls = 8, threshold = 0.05)
rug.fit(X_train, y_train[d['target']])
y_results['rug_pred'] = rug.predict(np.array(X_test))

# %% [markdown]
# ## inspect performance

# %%
# Confusion matrix
cm = pd.crosstab(y_results['y_test'], y_results['rug_pred'])
print ("Confusion matrix : \n", cm)

print('\nAccuracy  = %.4f' % accuracy_score(y_results['y_test'], y_results['rug_pred']))
print('F1 score  = %.4f' % f1_score(y_results['y_test'], y_results['rug_pred']))
# Out:
# Confusion matrix :
#  rug_pred    0   1
# y_test
# 0         102   8
# 1          29  40
#
# Accuracy  = 0.7933
# F1 score  = 0.6838

# %% [markdown]
# ### Questions
#
# **Q 5.2.1 – Evaluate the model performance.**
#
# ...
#
# **Q 5.2.2 – Explain the meaning of `rule_cost = Length()`.**
#
# ...

# %% [markdown]
# ## model interpretation
#
# ---
# ### GLOBAL

# %%
exp = Explainer(rug)
summary = exp.summarize_rule_metrics()
# Out:
# Total number of rules: 18
# Average rule length: 2.28

# %%
rules = exp.retrieve_rule_details(list(feature_names))
# Out:
# RULE 0:
# 2.50      < Age       <= inf       or null
# -inf      < Pclass_2  <= 0.50      or null
# -inf      < Sex_1     <= 0.50      and not null
# Class: 1
# Scaled rule weight: 1.0000
#
# RULE 1:
# -inf      < Age       <= 7.00      and not null
# -inf      < SibSp     <= 2.50      or null
# Class: 1
# Scaled rule weight: 0.6667
#
# RULE 2:
# -inf      < Sex_1     <= 0.50      and not null
# 8.04      < Fare      <= 14.85     and not null
# Class: 0
# Scaled rule weight: 0.6667
#
# RULE 3:
# 0.96      < Age       <= 2.50      or null
# -inf      < Pclass_1  <= 0.50      or null
# Class: 0
# Scaled rule weight: 0.6667
#
# RULE 4:
# -inf      < Age       <= 1.50      and not null
# Class: 1
# Scaled rule weight: 0.6667
#
# RULE 5:
# -inf      < Age       <= 11.50     and not null
# -inf      < Embarked_2 <= 0.50      and not null
# Class: 0
# Scaled rule weight: 0.6667
#
# RULE 6:
# 13.50     < Age       <= inf       or null
# -inf      < Fare      <= 26.14     or null
# 0.50      < Sex_1     <= inf       or null
# Class: 0
# Scaled rule weight: 0.3333
#
# RULE 7:
# -inf      < Age       <= 13.50     and not null
# -inf      < Fare      <= 26.14     or null
# 0.50      < Sex_1     <= inf       or null
# Class: 1
# Scaled rule weight: 0.3333
#
# RULE 8:
# 19.86     < Fare      <= 31.33     and not null
# 0.50      < Parch     <= inf       and not null
# Class: 0
# Scaled rule weight: 0.3333
#
# RULE 9:
# 17.43     < Fare      <= inf       and not null
# 12.00     < Age       <= inf       or null
# 0.50      < Pclass_1  <= inf       and not null
# Class: 0
# Scaled rule weight: 0.3333
#
# RULE 10:
# 24.81     < Fare      <= inf       and not null
# 0.50      < Pclass_2  <= inf       and not null
# -inf      < Sex_1     <= 0.50      and not null
# Class: 0
# Scaled rule weight: 0.3333
#
# RULE 11:
# 54.50     < Age       <= inf       and not null
# 14.85     < Fare      <= inf       or null
# Class: 0
# Scaled rule weight: 0.3333
#
# RULE 12:
# 77.01     < Fare      <= inf       and not null
# Class: 0
# Scaled rule weight: 0.3333
#
# RULE 13:
# -inf      < Fare      <= 24.81     or null
# 0.50      < Pclass_2  <= inf       and not null
# -inf      < Sex_1     <= 0.50      and not null
# Class: 1
# Scaled rule weight: 0.3333
#
# RULE 14:
# 37.00     < Fare      <= 52.28     and not null
# -inf      < Pclass_1  <= 0.50      or null
# Class: 0
# Scaled rule weight: 0.3333
#
# RULE 15:
# 52.28     < Fare      <= 59.19     and not null
# -inf      < Pclass_1  <= 0.50      or null
# Class: 1
# Scaled rule weight: 0.3333
#
# RULE 16:
# 2.50      < SibSp     <= inf       and not null
# 26.14     < Fare      <= inf       and not null
# 0.50      < Sex_1     <= inf       or null
# Class: 0
# Scaled rule weight: 0.3333
#
# RULE 17:
# -inf      < Age       <= 12.00     and not null
# 0.50      < Pclass_1  <= inf       and not null
# Class: 1
# Scaled rule weight: 0.3333

# %% [markdown]
# ### Questions
#
# **Q 5.2.2 – Evaluate the global interpretability of the model.**
#
# ...

# %% [markdown]
# ---
# ### LOCAL

# %%
rule_coverage_metrics = exp.evaluate_rule_coverage_metrics(X_test, info=True)
# Out:
# Number of instances not covered by any rule: 12
# Average number of rules per sample: 1.37
# Average length of rules per sample: 2.53

# %%
i = 9
print(f'True and predicted values for sample at index {i}:')
print(y_results.loc[i,:], '\n')
print(f'Sample {i} features:')
X_test.loc[[i]]
# Out:
# True and predicted values for sample at index 9:
# y_test      1
# rug_pred    0
# Name: 9, dtype: int64
#
# Sample 9 features:
#     Age  SibSp  Parch  Fare  Sex_1  Embarked_1  Embarked_2  Pclass_1  Pclass_2
# 9  19.0      0      0  8.05      1           0           1         0         1

# %%
exp.find_applicable_rules_for_samples(X_test.iloc[[i]], feature_names=list(feature_names), info=True)
# Out:
# Rules for instance 0
# RULE 6:
# 13.50     < Age       <= inf       or null
# -inf      < Fare      <= 26.14     or null
# 0.50      < Sex_1     <= inf       or null
# Class: 0
# Scaled rule weight: 0.3333
# [[6]]

# %% [markdown]
# ### Questions
#
# **Q 5.2.3 – Take a look at the local explanation for the sample with index 7 of the test set. Explain how the prediction is made.**
#
# ...
#
# **Q 5.2.4 – Explain the main difference between RUG and the algorithm here that produces a decision list.**
#
# ...
